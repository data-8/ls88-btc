# %%
from datascience import *
import numpy as np
import math
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd
# %matplotlib inline

# %% [markdown]
# A Google Form Called
# Sample Survey - Lec6 - Mobile Payments
# https://drive.google.com/open?id=1rgM_iKn7bmSfjnXjPA6rX6JwX21te0DXaWAWNj2Q30w
#
# The outcome data were in
# https://docs.google.com/spreadsheets/d/16VIvrszKX91g46PCibXqC9oPJijBzomlCSOv495Llws/edit#gid=2035822366

# %%
# Read in the downloaded csv file
myfile = 'MobileSurveyOct9 - Form Responses 1.csv'
mobilemoney = Table.read_table(myfile)

# Take a look at the table
mobilemoney
# Out:
# Timestamp          | Score | Question 1 - What kind of mobile device do you have? | Do you use a mobile payment app? | How many time per month do you make a mobile payment?  | What share of your friends use mobile payments | How safe do you think mobile payments are? | Question 4 - Short Answer | For what purposes do you use mobile payments? Check all that apply. | Unnamed: 9 | How much money do you expend on mobile payments on average per month? | What is the maximum amount of money that you are willing to transfer through the app? | Do you prefer using cash or mobile payments for transactions? | What is the maximum amount of money would you be willing to transfer? | Would you want businesses to begin using these kinds of payment apps? (i.e. Venmo) | How much money do you receive on mobile payments on average per month? | Unnamed: 16 | Who do you pay/ receive payments from with mobile transactions? | Do you use cryptocurrency?
# ...

# %%
# all the variable names
list(mobilemoney)
# Out:
# ['Timestamp',
#  'Score',
#  'Question 1 - What kind of mobile device do you have?',
#  'Do you use a mobile payment app?',
#  'How many time per month do you make a mobile payment? ',
#  'What share of your friends use mobile payments',
#  'How safe do you think mobile payments are?',
#  'Question 4 - Short Answer',
#  'For what purposes do you use mobile payments? Check all that apply.',
#  'Unnamed: 9',
#  'How much money do you expend on mobile payments on average per month?',
#  'What is the maximum amount of money that you are willing to transfer through the app?',
#  'Do you prefer using cash or mobile payments for transactions?',
#  'What is the maximum amount of money would you be willing to transfer?',
#  'Would you want businesses to begin using these kinds of payment apps? (i.e. Venmo)',
#  'How much money do you receive on mobile payments on average per month?',
#  'Unnamed: 16',
#  'Who do you pay/ receive payments from with mobile transactions?',
# ...

# %%
# Read in xls file - to Pandas and Tables 
#mobileDF = pd.DataFrame(pd.read_excel('mobile.xls'))
#mobiletable= Table.from_df(WGP_baseline)
#mobiletable

# %%
mobilemoney.group("Question 1 - What kind of mobile device do you have?")
# Out:
# Question 1 - What kind of mobile device do you have? | count
# Android                                              | 2
# Apple                                                | 20

# %%
mobilemoney.hist("How safe do you think mobile payments are?")

# %%
mobilemoney.hist('What share of your friends use mobile payments')

# %%
mobilemoney.barh('variable name')

# %%
mobilemoney.scatter("How safe do you think mobile payments are?", "What share of your friends use mobile payments")
