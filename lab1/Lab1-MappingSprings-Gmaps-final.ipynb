# %%
#from datascience import *
#import numpy as np
#import math
#import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# This homework will be working with a module in Jupyter called Gmaps
# the documentation is here
# http://jupyter-gmaps.readthedocs.io/en/latest/gmaps.html
# and it is worth a short read through
#
# For Data 8 users, a basic mapping program is included in the datascience module
# it is called Folium and makes open source maps from python data
# the documentation is here
# http://folium.readthedocs.io/en/latest/index.html
#
# Unfortunately I could not figure out how to code it to change the base layer to a satelite picture, and the Open Street Map base layer is not so useful in rural Western Kenya.  To get the satellite layer I needed to work with Google Maps.

# %%
# if you want to run this on a local machine you may need to do the following
# at the terminal prompt need to do $pip install gmaps
# at the terminal prompt need to do $jupyter nbextension enable --py gmaps
# may have to quite jupyter and restart terminal and then do the above prompt
# need a GMAPS API token  - mine is AIzaSyAEiYVYysCqAcaekG_XA-cPtgXAHPXTv4o
#  This code is following along from http://jupyter-gmaps.readthedocs.io/en/latest/gmaps.html

import gmaps
import gmaps.datasets

gmaps.configure(api_key="AIzaSyAEiYVYysCqAcaekG_XA-cPtgXAHPXTv4o") # Fill in with your API key

# %% [markdown]
# We will strart by reading in a dataset of the GPS coordinates of the springs that are used in the WaterGuard Promotion (WGP) study.  These springs were randomized into seven different treatment arms.  The springs are identified by a unique numerical id tag, and the common name in the local language.
#
#
# This is going to make  a pandas dataframe, which is a lot like the tables we have been working with in the datascience module

# %%
#springsGPS = 'WGPgps_forData8.csv'
springsGPS= pd.read_csv('WGPgps_forData8.csv')

# Take a look at the table
springsGPS
# Out:
#     a2_spring_id   a3_spring_name  treatment_arm     gpsn1     gpse1  \
# 0           1010    JIKAZE SOWETO              6  0.399850  34.49003
# 1           1013        ROHO SAFI              4  0.398933  34.48985
# 2           1014           OTWOMA              6  0.339083  34.43550
# 3           1015           MUKOYA              5  0.358317  34.44122
# 4           1021           OKELLO              6  0.355983  34.43142
# 5           5001      NAKHALIRO A              6  0.439167  34.39919
# 6           5002    NAKHALIRO 'B'              4  0.439033  34.40192
# 7           5004           OSIMBO              1  0.411583  34.36442
# 8           5007            TANDE              7  0.433667  34.43255
# 9           5008         MUKABANA              6  0.408483  34.45912
# 10          5009          F. AUKA              7  0.404933  34.45757
# 11          5012           J WERE              2  0.398350  34.40227
# 12          5013           MURIKA              3  0.432850  34.43510
# 13          5017          MULAMBA              6  0.416117  34.37390
# 14          5019           ANDIWO              5  0.294950  34.39567
# 15          5020           NAMANO              6  0.386300  34.43205
# 16          5023         PHILLIPO              1  0.426517  34.37057
# 17          5025     RUPIA/MUSOLO              1  0.397883  34.43623
# 18          5028          NABONWE              5  0.401600  34.43010
# 19          5029         WAMUKOYA              4  0.413500  34.43533
# 20          5030          ONYANGO              5  0.337050  34.41133
# 21          5031       PETRO JUMA              7  0.427167  34.43573
# 22          5037          ONYANGO              7  0.414550  34.38295
# 23          5042            OKOTH              7  0.466200  34.42180
# 24          5044           OTIALO              6  0.352350  34.39887
# 25          5046          OTANG'O              1  0.447150  34.42823
# 26          5047           KITUYI              6  0.438683  34.42863
# 27          5050         MWENJERE              7  0.398033  34.45537
# 28          5051           MAPESA              3  0.454050  34.42311
# 29          5052          IKWENYI              5  0.461667  34.42743
# ..           ...              ...            ...       ...       ...
# 58          5119           TONGWA              2  0.355950  34.42132
# 59          5122          AMBANDA              7  0.400267  34.42935
# 60          5126            SARAH              5  0.413983  34.38292
# 61          5130           MALIBA              5  0.406900  34.40498
# 62          5132          KOMBWAS              4  0.329483  34.40100
# 63          5139            TONDE              6  0.457567  34.37598
# 64          5140          NABASWA              5  0.451933  34.37630
# 65          5144          MASINDE              7  0.390817  34.40317
# 66          5145          ANGWETE              5  0.391283  34.44418
# 67          5151            WASWA              6  0.424200  34.37277
# 68          5152          NABWIRE              5  0.444417  34.39737
# 69          5155            YWAYA              1  0.438733  34.46041
# 70          5157            WAKHU              7  0.289433  34.40443
# 71          5160            JELLA              7  0.394783  34.44393
# 72          5161             JOMO              2  0.452733  34.39323
# 73          5164           KALORI              6  0.416067  34.39272
# 74          5165             OPIO              1  0.341767  34.40350
# 75          5166          WERAMBO              6  0.340717  34.40888
# 76          5168          WABWIRE              7  0.431150  34.36172
# 77          5173  LAMBERT WESONGA              6  0.449000  34.41173
# 78          5174            OLESO              5  0.305183  34.40443
# 79          5179          DAMIANO              5  0.346700  34.41460
# 80          5181          MASANGA              4  0.345133  34.40875
# 81          5184            OPULI              6  0.414317  34.40635
# 82          5185            AKAYA              1  0.416217  34.41030
# 83          5189           WAFULA              1  0.434567  34.40395
# 84          5192          WANJIRI              7  0.331183  34.39580
# 85          5193          RAPANDO              3  0.428150  34.45635
# 86          5195            SARAI              7  0.345483  34.40408
# 87          5196          MUSUMBA              7  0.422200  34.46242
#
#               gps1all
# 0     .39985,34.49003
# 1   .3989333,34.48985
# 2    .3390833,34.4355
# 3   .3583167,34.44122
# 4   .3559833,34.43142
# 5   .4391667,34.39919
# 6   .4390333,34.40192
# 7   .4115833,34.36442
# 8   .4336667,34.43255
# 9   .4084833,34.45912
# 10  .4049333,34.45757
# 11    .39835,34.40227
# 12     .43285,34.4351
# 13   .4161167,34.3739
# 14    .29495,34.39567
# 15     .3863,34.43205
# 16  .4265167,34.37057
# 17  .3978833,34.43623
# 18      .4016,34.4301
# 19     .4135,34.43533
# 20    .33705,34.41133
# 21  .4271667,34.43573
# 22    .41455,34.38295
# 23      .4662,34.4218
# 24    .35235,34.39887
# 25    .44715,34.42823
# 26  .4386833,34.42863
# 27  .3980333,34.45537
# 28    .45405,34.42311
# 29  .4616667,34.42743
# ..                ...
# 58    .35595,34.42132
# 59  .4002667,34.42935
# 60  .4139833,34.38292
# 61     .4069,34.40498
# 62    .3294833,34.401
# 63  .4575667,34.37598
# 64   .4519333,34.3763
# 65  .3908167,34.40317
# 66  .3912833,34.44418
# 67     .4242,34.37277
# 68  .4444167,34.39737
# 69  .4387333,34.46041
# 70  .2894333,34.40443
# 71  .3947833,34.44393
# 72  .4527333,34.39323
# 73  .4160667,34.39272
# 74   .3417667,34.4035
# 75  .3407167,34.40888
# 76    .43115,34.36172
# 77      .449,34.41173
# 78  .3051833,34.40443
# 79      .3467,34.4146
# 80  .3451333,34.40875
# 81  .4143167,34.40635
# 82   .4162167,34.4103
# 83  .4345667,34.40395
# 84   .3311833,34.3958
# 85    .42815,34.45635
# 86  .3454833,34.40408
# 87     .4222,34.46242
#
# [88 rows x 6 columns]

# %%
# now we will make a table with just the North and East Gps columns 
#in order to make it play nice with Gmaps


locations = springsGPS[["gpsn1", "gpse1"]]
locations
# Out:
#        gpsn1     gpse1
# 0   0.399850  34.49003
# 1   0.398933  34.48985
# 2   0.339083  34.43550
# 3   0.358317  34.44122
# 4   0.355983  34.43142
# 5   0.439167  34.39919
# 6   0.439033  34.40192
# 7   0.411583  34.36442
# 8   0.433667  34.43255
# 9   0.408483  34.45912
# 10  0.404933  34.45757
# 11  0.398350  34.40227
# 12  0.432850  34.43510
# 13  0.416117  34.37390
# 14  0.294950  34.39567
# 15  0.386300  34.43205
# 16  0.426517  34.37057
# 17  0.397883  34.43623
# 18  0.401600  34.43010
# 19  0.413500  34.43533
# 20  0.337050  34.41133
# 21  0.427167  34.43573
# 22  0.414550  34.38295
# 23  0.466200  34.42180
# 24  0.352350  34.39887
# 25  0.447150  34.42823
# 26  0.438683  34.42863
# 27  0.398033  34.45537
# 28  0.454050  34.42311
# 29  0.461667  34.42743
# ..       ...       ...
# 58  0.355950  34.42132
# 59  0.400267  34.42935
# 60  0.413983  34.38292
# 61  0.406900  34.40498
# 62  0.329483  34.40100
# 63  0.457567  34.37598
# 64  0.451933  34.37630
# 65  0.390817  34.40317
# 66  0.391283  34.44418
# 67  0.424200  34.37277
# 68  0.444417  34.39737
# 69  0.438733  34.46041
# 70  0.289433  34.40443
# 71  0.394783  34.44393
# 72  0.452733  34.39323
# 73  0.416067  34.39272
# 74  0.341767  34.40350
# 75  0.340717  34.40888
# 76  0.431150  34.36172
# 77  0.449000  34.41173
# 78  0.305183  34.40443
# 79  0.346700  34.41460
# 80  0.345133  34.40875
# 81  0.414317  34.40635
# 82  0.416217  34.41030
# 83  0.434567  34.40395
# 84  0.331183  34.39580
# 85  0.428150  34.45635
# 86  0.345483  34.40408
# 87  0.422200  34.46242
#
# [88 rows x 2 columns]

# %%
# The general syntax is make a map, 
#add these markers or symbols, 
#then display the map
# once the map is displayed, click the tab to display the satellite view

fig = gmaps.figure()
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)
fig

# %%
# Let's change the color of the symbols 

fig = gmaps.figure()
symbols = gmaps.symbol_layer(locations,fill_color="red")
fig.add_layer(symbols)
fig

# %% [markdown]
# Now the most interesting bit of data is still not being used, the Treatment Arm
# Lets assign different colors to the different treatment arms
# So that when we map it we can look and see if the arms appear to be randomly distributed
#
# The following is function, that assigns the 1-7 of the treatment arms to a set of colors
#
# Here is the colors reference if you are interested!
# https://www.w3.org/TR/css3-color/#html4

# %%
def color(arm):
    if arm == 1:
        return 'fuschia'
    elif arm == 2:
        return 'red'
    elif arm == 3:
        return 'purple'
    elif arm == 4:
        return 'green'
    elif arm == 5:
        return 'blue'
    elif arm == 6:
        return 'olive'
    elif arm == 7:
        return 'teal'

# %%
# Using the .apply method, you can apply any function to a data frame
springsGPS['color'] = springsGPS['treatment_arm'].apply(lambda arm: color(arm)).tolist()
springsGPS
# Out:
#     a2_spring_id   a3_spring_name  treatment_arm     gpsn1     gpse1  \
# 0           1010    JIKAZE SOWETO              6  0.399850  34.49003
# 1           1013        ROHO SAFI              4  0.398933  34.48985
# 2           1014           OTWOMA              6  0.339083  34.43550
# 3           1015           MUKOYA              5  0.358317  34.44122
# 4           1021           OKELLO              6  0.355983  34.43142
# 5           5001      NAKHALIRO A              6  0.439167  34.39919
# 6           5002    NAKHALIRO 'B'              4  0.439033  34.40192
# 7           5004           OSIMBO              1  0.411583  34.36442
# 8           5007            TANDE              7  0.433667  34.43255
# 9           5008         MUKABANA              6  0.408483  34.45912
# 10          5009          F. AUKA              7  0.404933  34.45757
# 11          5012           J WERE              2  0.398350  34.40227
# 12          5013           MURIKA              3  0.432850  34.43510
# 13          5017          MULAMBA              6  0.416117  34.37390
# 14          5019           ANDIWO              5  0.294950  34.39567
# 15          5020           NAMANO              6  0.386300  34.43205
# 16          5023         PHILLIPO              1  0.426517  34.37057
# 17          5025     RUPIA/MUSOLO              1  0.397883  34.43623
# 18          5028          NABONWE              5  0.401600  34.43010
# 19          5029         WAMUKOYA              4  0.413500  34.43533
# 20          5030          ONYANGO              5  0.337050  34.41133
# 21          5031       PETRO JUMA              7  0.427167  34.43573
# 22          5037          ONYANGO              7  0.414550  34.38295
# 23          5042            OKOTH              7  0.466200  34.42180
# 24          5044           OTIALO              6  0.352350  34.39887
# 25          5046          OTANG'O              1  0.447150  34.42823
# 26          5047           KITUYI              6  0.438683  34.42863
# 27          5050         MWENJERE              7  0.398033  34.45537
# 28          5051           MAPESA              3  0.454050  34.42311
# 29          5052          IKWENYI              5  0.461667  34.42743
# ..           ...              ...            ...       ...       ...
# 58          5119           TONGWA              2  0.355950  34.42132
# 59          5122          AMBANDA              7  0.400267  34.42935
# 60          5126            SARAH              5  0.413983  34.38292
# 61          5130           MALIBA              5  0.406900  34.40498
# 62          5132          KOMBWAS              4  0.329483  34.40100
# 63          5139            TONDE              6  0.457567  34.37598
# 64          5140          NABASWA              5  0.451933  34.37630
# 65          5144          MASINDE              7  0.390817  34.40317
# 66          5145          ANGWETE              5  0.391283  34.44418
# 67          5151            WASWA              6  0.424200  34.37277
# 68          5152          NABWIRE              5  0.444417  34.39737
# 69          5155            YWAYA              1  0.438733  34.46041
# 70          5157            WAKHU              7  0.289433  34.40443
# 71          5160            JELLA              7  0.394783  34.44393
# 72          5161             JOMO              2  0.452733  34.39323
# 73          5164           KALORI              6  0.416067  34.39272
# 74          5165             OPIO              1  0.341767  34.40350
# 75          5166          WERAMBO              6  0.340717  34.40888
# 76          5168          WABWIRE              7  0.431150  34.36172
# 77          5173  LAMBERT WESONGA              6  0.449000  34.41173
# 78          5174            OLESO              5  0.305183  34.40443
# 79          5179          DAMIANO              5  0.346700  34.41460
# 80          5181          MASANGA              4  0.345133  34.40875
# 81          5184            OPULI              6  0.414317  34.40635
# 82          5185            AKAYA              1  0.416217  34.41030
# 83          5189           WAFULA              1  0.434567  34.40395
# 84          5192          WANJIRI              7  0.331183  34.39580
# 85          5193          RAPANDO              3  0.428150  34.45635
# 86          5195            SARAI              7  0.345483  34.40408
# 87          5196          MUSUMBA              7  0.422200  34.46242
#
#               gps1all    color
# 0     .39985,34.49003    olive
# 1   .3989333,34.48985    green
# 2    .3390833,34.4355    olive
# 3   .3583167,34.44122     blue
# 4   .3559833,34.43142    olive
# 5   .4391667,34.39919    olive
# 6   .4390333,34.40192    green
# 7   .4115833,34.36442  fuschia
# 8   .4336667,34.43255     teal
# 9   .4084833,34.45912    olive
# 10  .4049333,34.45757     teal
# 11    .39835,34.40227      red
# 12     .43285,34.4351   purple
# 13   .4161167,34.3739    olive
# 14    .29495,34.39567     blue
# 15     .3863,34.43205    olive
# 16  .4265167,34.37057  fuschia
# 17  .3978833,34.43623  fuschia
# 18      .4016,34.4301     blue
# 19     .4135,34.43533    green
# 20    .33705,34.41133     blue
# 21  .4271667,34.43573     teal
# 22    .41455,34.38295     teal
# 23      .4662,34.4218     teal
# 24    .35235,34.39887    olive
# 25    .44715,34.42823  fuschia
# 26  .4386833,34.42863    olive
# 27  .3980333,34.45537     teal
# 28    .45405,34.42311   purple
# 29  .4616667,34.42743     blue
# ..                ...      ...
# 58    .35595,34.42132      red
# 59  .4002667,34.42935     teal
# 60  .4139833,34.38292     blue
# 61     .4069,34.40498     blue
# 62    .3294833,34.401    green
# 63  .4575667,34.37598    olive
# 64   .4519333,34.3763     blue
# 65  .3908167,34.40317     teal
# 66  .3912833,34.44418     blue
# 67     .4242,34.37277    olive
# 68  .4444167,34.39737     blue
# 69  .4387333,34.46041  fuschia
# 70  .2894333,34.40443     teal
# 71  .3947833,34.44393     teal
# 72  .4527333,34.39323      red
# 73  .4160667,34.39272    olive
# 74   .3417667,34.4035  fuschia
# 75  .3407167,34.40888    olive
# 76    .43115,34.36172     teal
# 77      .449,34.41173    olive
# 78  .3051833,34.40443     blue
# 79      .3467,34.4146     blue
# 80  .3451333,34.40875    green
# 81  .4143167,34.40635    olive
# 82   .4162167,34.4103  fuschia
# 83  .4345667,34.40395  fuschia
# 84   .3311833,34.3958     teal
# 85    .42815,34.45635   purple
# 86  .3454833,34.40408     teal
# 87     .4222,34.46242     teal
#
# [88 rows x 7 columns]

# %%
fig = gmaps.figure()
symbols = gmaps.symbol_layer(locations,
                             stroke_color=springsGPS['color'].tolist(),
                             fill_color=springsGPS['color'].tolist()
                            )
fig.add_layer(symbols)
fig

# %% [markdown]
# Ok - take a look at that map!
# Do the colors seem randomly distributed ?
# In fact the randomization was performed on just a list of the springs using a random number generator.  It did not take spatial distribution into effect.

# %% [markdown]
# ## Question 1  - Thought Experiment - Spatial Randomization
# 1.1 What could you do to test whether the Treatment arms are spatially distributed.
#
# 1.2 What could you do to randomize the treatment arms over space.

# %% [markdown]
# Now I am going to give you a few more GPS points that aren't from the study  - but are in the region and could be of interest. We will read them into another dataframe

# %%
# the 5 additional points are called extras
extras= pd.DataFrame.from_items([('Lat', [0.456378, 0.11807, -0.010254,-0.077914,0.363017]), 
                                 ('Long', [34.122355, 34.534930, 34.345290,34.676680,34.503054])])

# %%
#Now we draw the map, add the springs layer as a symbol and the extras layer as a marker 
# Dont forget to switch to satellite view!
fig = gmaps.figure()
symbols = gmaps.symbol_layer(locations,
                             stroke_color=springsGPS['color'].tolist(),
                             fill_color=springsGPS['color'].tolist()
                            )
fig.add_layer(symbols)
extralocs = gmaps.marker_layer(extras)
fig.add_layer(extralocs)

fig

# %%
# Here is the simpler version with just the extras
fig = gmaps.figure()
extralocs = gmaps.marker_layer(extras)
fig.add_layer(extralocs)
fig

# %% [markdown]
# ## Question 2 - Treasure hunt for 5 data points
# The question is can you identify the 5 extra data points  - and provide some rationale for why they are interesting?  The key will be to zoom in on the satellite, look around, and see if you can find/see/ or google the names of what you find!
#
# Hints?...  ok.... one is of interest to our study, one is of interest to US politics, one is of interest to the debate in international development, one is of interest to the study of child diarrhea, and one is of interest because how it changes the landscape.
#
# Write a few sentences in each of the boxes below

# %% [markdown]
# 2.1 - Extras 1 is:

# %% [markdown]
# 2.2 - Extras 2 is:

# %% [markdown]
# 2.3 - Extras 3 is:

# %% [markdown]
# 2.4 - Extras 4 is:

# %% [markdown]
# 2.5 - Extras 5 is:
